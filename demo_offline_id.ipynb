# %% [markdown]
# # 1. identity extraction

# %%
import os
import argparse
import numpy as np 
from tqdm import  tqdm
from glob import glob
from embedding_distribution import load_image, get_frame_id, frames_per_video
from config.config import Config
from torch.nn import DataParallel
from models import resnet_face18
import torch
import cv2
torch.cuda.empty_cache()

test_model_path= "./pretrained/resnet18_110.pth"
opt = Config()
model = resnet_face18(opt.use_se)
model = DataParallel(model)
model.load_state_dict(torch.load(test_model_path))
model.to(torch.device("cuda"))
model.eval()

def video_id_extraction(path, 
                        save, 
                        len_save, 
                        batch_size = 16,
                        compress=None, 
                        noise=None):
    whole_set_ids = None
    video_length = []
    video_list = glob(path+"/*")
    video_list.sort()
    for video in tqdm(video_list):
        batch_frames = None
        video_ids = None
        batch_count = 0
        video_frames = glob(video+"/*")
        if len(glob(video+"/*")) < 1:
          print("empty folder", video)
          continue
        frame_list = glob(video+"/*")
        for frame in frame_list:
            batch_count += 1
            try:
             single_image = load_image(frame, compress=compress, noise=noise)
            except Exception as e:
              print("blocked-", frame)
              print("error-",e)
              del e
              continue
            if batch_frames is None:
                batch_frames = single_image
            else:
                batch_frames = np.concatenate((batch_frames, single_image), axis=0)
            if not batch_count % batch_size or batch_count==len(video_frames):
                batch_ids = get_frame_id(model, batch_frames, batch_size=batch_size)
                batch_frames = None
                if video_ids is None:
                    video_ids = batch_ids
                else:
                    video_len1 = video_ids.shape[0]
                    video_ids = np.concatenate((video_ids, batch_ids), axis=0)
        if whole_set_ids is None:
            whole_set_ids = video_ids
        else:
            whole_set_ids = np.concatenate((whole_set_ids, video_ids), axis=0)
        video_length.append(len(video_frames))
    video_length = np.array(video_length) 
    print("video_length", sum(video_length))
    print("whole_set_ids", len(whole_set_ids))
    np.save(save, whole_set_ids)
    np.save(len_save,video_length)
    del whole_set_ids, video_length

# %% [markdown]
# ### 1.1. FaceForensics++  dataset

# %%
save_root = "./id_vectors/FFpp/"

paths=["/home/baoping/FaceForensics++/manipulated_sequences/NeuralTextures/raw/aligned_faces", \
       "/home/baoping/FaceForensics++/manipulated_sequences/FaceSwap/raw/aligned_faces", \
       "/home/baoping/FaceForensics++/manipulated_sequences/Face2Face/raw/aligned_faces", \
       "/home/baoping/FaceForensics++/manipulated_sequences/Deepfakes/raw/aligned_faces", \
       "/home/baoping/FaceForensics++/original_sequences/youtube/raw/aligned_faces"  ]

ids_save_path = ["ffpp_nt_ids.npy", "ffpp_fs_ids.npy", "ffpp_ff_ids.npy", "ffpp_df_ids.npy", "ffpp_real_ids.npy"]#
len_save_path = ["ffpp_nt_lens.npy", "ffpp_fs_lens.npy", "ffpp_ff_lens.npy", "ffpp_df_lens.npy", "ffpp_real_lens.npy"]#
for idx, p in enumerate(paths):
    video_id_extraction(p, 
                        os.path.join( ids_save_path[idx] ), 
                        os.path.join( len_save_path[idx]) )

# %%
import numpy as np
import os

def set_merge(fake_id_list, real_length):
    fake_type_count = len(fake_id_list)
    real_video_count = real_length
    fake_video_count = int(real_video_count // fake_type_count)
    print("video count", real_video_count, fake_video_count)
    ret_list = []
    for i in fake_id_list:
        ret_list += i[:fake_video_count]
    return ret_list
ffpp_real_ids = "./id_vectors/FFpp/ffpp_real_ids.npy"
ffpp_real_len = "./id_vectors/FFpp/ffpp_real_lens.npy"
ffpp_df_ids = "./id_vectors/FFpp/ffpp_df_ids.npy"
ffpp_df_len = "./id_vectors/FFpp/ffpp_df_lens.npy"
ffpp_ff_ids = "./id_vectors/FFpp/ffpp_ff_ids.npy"
ffpp_ff_len = "./id_vectors/FFpp/ffpp_ff_lens.npy"
ffpp_fs_ids = "./id_vectors/FFpp/ffpp_fs_ids.npy"
ffpp_fs_len = "./id_vectors/FFpp/ffpp_fs_lens.npy"
ffpp_nt_ids = "./id_vectors/FFpp/ffpp_nt_ids.npy"
ffpp_nt_len = "./id_vectors/FFpp/ffpp_nt_lens.npy"

fake_ids_list = [ffpp_df_ids, ffpp_ff_ids, ffpp_fs_ids, ffpp_nt_ids]
fake_len_list = [ffpp_df_len, ffpp_ff_len, ffpp_fs_len, ffpp_nt_len]

real_ids = np.load(ffpp_real_ids)
real_len = np.load(ffpp_real_len, allow_pickle=True)
print("real shapes", real_ids.shape, real_len.shape)

merged_ids = None
merged_len = None
for i,l in zip(fake_ids_list,fake_len_list):#range(4):
    fake_ids = np.load(i)
    fake_len = np.load(l, allow_pickle=True)
    if merged_ids is None:
        merged_ids = fake_ids
        merged_len = fake_len
    else:
        merged_ids = np.concatenate((merged_ids,fake_ids))
        merged_len = np.concatenate((merged_len,fake_len))
np.save("./id_vectors/FFpp/ffpp_fake_ids.npy", merged_ids)
np.save("./id_vectors/FFpp/ffpp_fake_len.npy", merged_len)

# %% [markdown]
# ### 1.2. CelebDF

# %%
save_root = "./id_vectors/CelebDF/"

paths=["/media/baoping/8TSGHDD/CelebDF/Celeb-real/aligned_faces", \
       "/media/baoping/8TSGHDD/CelebDF/Celeb-synthesis/aligned_faces"]

ids_save_path = ["celebdf_real.npy", "celebdf_fake.npy"]
len_save_path = ["celebdf_real_lens.npy", "celebdf_fake_lens.npy"]
for idx, p in enumerate(paths):
    video_id_extraction(p, 
                        os.path.join(save_root, ids_save_path[idx]), 
                        os.path.join(save_root, len_save_path[idx]))

# %% [markdown]
# ### 1.3. DFD

# %%
save_root = "./id_vectors/DFD/"

paths=["/media/baoping/8TSGHDD/DeepFakeDetection/real", \
       "/media/baoping/8TSGHDD/DeepFakeDetection/fake"]

ids_save_path = ["dfd_real.npy", "dfd_fake.npy"]
len_save_path = ["dfd_real_lens.npy", "dfd_fake_lens.npy"]
for idx, p in enumerate(paths):
    video_id_extraction(p, 
                        os.path.join(save_root, ids_save_path[idx]), 
                        os.path.join(save_root, len_save_path[idx]))

# %% [markdown]
# ### 1.4.Deeper

# %%
save_root = "./id_vectors/Deeper/"

paths=["/media/baoping/8TSGHDD/DeeperForensics1.0/manipulated_videos/end_to_end"]

ids_save_path = ["deeper_fake.npy"]
len_save_path = ["deeper_fake_lens.npy"]
for idx, p in enumerate(paths):
    video_id_extraction(p, 
                        os.path.join(save_root, ids_save_path[idx]), 
                        os.path.join(save_root, len_save_path[idx]))

# %% [markdown]
# # 2. TI2Net training

# %%
# !python train.py \
--fake_selection="all" \
--model="test" \
--train_contrastive=1 \
--real_path="./id_vectors/FFpp/ffpp_real_ids.npy" \
--real_len_path="./id_vectors/FFpp/ffpp_real_lens.npy" \
--fake_path="./id_vectors/FFpp/ffpp_fake_ids.npy" \
--fake_len_path="./id_vectors/FFpp/ffpp_fake_lens.npy"
# Out:
# Using device: cuda:0
# train set and test and set get
# Training contrastive module
# model TI2Net(
#   (dropout_landmark): LandmarkDropout()
#   (rnn): GRU(1024, 512, batch_first=True, bidirectional=True)
#   (dropout_feature): Dropout(p=0.7, inplace=False)
#   (linear_1): Linear(in_features=1024, out_features=128, bias=True)
#   (relu): ReLU()
#   (linear_2): Linear(in_features=128, out_features=2, bias=True)
#   (output): Softmax(dim=1)
# )
# Using TripletMarginLoss
# train iteration each epoch: 2997
# test iteration each epoch: 999
# ***************************************************************************************************
# epoch:1 training: emb_loss:0.3214 clf_loss:0.6032, loss:0.6353, train_acc:0.6607save the model to ./weights/torch/test.pth
# epoch:1 testing: test_seq_acc:0.5315, test_seq_auc:0.7059, test_video_acc:0.5315, test_video_auc:0.7059save the model to ./weights/torch/test.pth
# epoch:1 summary: best_seq_acc:0.5315 best_seq_auc:0.7059 best_video_acc:0.5315 best_video_auc:0.7059save the model to ./weights/torch/test.pth
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:2 training: emb_loss:0.2302 clf_loss:0.5713, loss:0.5943, train_acc:0.681
# epoch:2 testing: test_seq_acc:0.519, test_seq_auc:0.7399, test_video_acc:0.519, test_video_auc:0.7399
# epoch:2 summary: best_seq_acc:0.5315 best_seq_auc:0.7399 best_video_acc:0.5315 best_video_auc:0.7399
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:3 training: emb_loss:0.1834 clf_loss:0.5665, loss:0.5849, train_acc:0.6889
# epoch:3 testing: test_seq_acc:0.5265, test_seq_auc:0.8202, test_video_acc:0.5265, test_video_auc:0.8202
# epoch:3 summary: best_seq_acc:0.5315 best_seq_auc:0.8202 best_video_acc:0.5315 best_video_auc:0.8202
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:4 training: emb_loss:0.1753 clf_loss:0.5584, loss:0.576, train_acc:0.7098
# epoch:4 testing: test_seq_acc:0.4875, test_seq_auc:0.7693, test_video_acc:0.4875, test_video_auc:0.7693
# epoch:4 summary: best_seq_acc:0.5315 best_seq_auc:0.8202 best_video_acc:0.5315 best_video_auc:0.8202
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:5 training: emb_loss:0.1668 clf_loss:0.5386, loss:0.5553, train_acc:0.7502
# epoch:5 testing: test_seq_acc:0.482, test_seq_auc:0.8214, test_video_acc:0.482, test_video_auc:0.8214
# epoch:5 summary: best_seq_acc:0.5315 best_seq_auc:0.8214 best_video_acc:0.5315 best_video_auc:0.8214
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:6 training: emb_loss:0.1431 clf_loss:0.5249, loss:0.5392, train_acc:0.7734save the model to ./weights/torch/test.pth
# epoch:6 testing: test_seq_acc:0.5415, test_seq_auc:0.8418, test_video_acc:0.5415, test_video_auc:0.8418save the model to ./weights/torch/test.pth
# epoch:6 summary: best_seq_acc:0.5415 best_seq_auc:0.8418 best_video_acc:0.5415 best_video_auc:0.8418save the model to ./weights/torch/test.pth
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:7 training: emb_loss:0.1255 clf_loss:0.5025, loss:0.5151, train_acc:0.7985
# epoch:7 testing: test_seq_acc:0.5285, test_seq_auc:0.8348, test_video_acc:0.5285, test_video_auc:0.8348
# epoch:7 summary: best_seq_acc:0.5415 best_seq_auc:0.8418 best_video_acc:0.5415 best_video_auc:0.8418
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:8 training: emb_loss:0.1198 clf_loss:0.4912, loss:0.5032, train_acc:0.8138save the model to ./weights/torch/test.pth
# epoch:8 testing: test_seq_acc:0.5531, test_seq_auc:0.8615, test_video_acc:0.5531, test_video_auc:0.8615save the model to ./weights/torch/test.pth
# epoch:8 summary: best_seq_acc:0.5531 best_seq_auc:0.8615 best_video_acc:0.5531 best_video_auc:0.8615save the model to ./weights/torch/test.pth
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:9 training: emb_loss:0.1099 clf_loss:0.4845, loss:0.4955, train_acc:0.8182
# epoch:9 testing: test_seq_acc:0.515, test_seq_auc:0.8677, test_video_acc:0.515, test_video_auc:0.8677
# epoch:9 summary: best_seq_acc:0.5531 best_seq_auc:0.8677 best_video_acc:0.5531 best_video_auc:0.8677
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:10 training: emb_loss:0.1015 clf_loss:0.4717, loss:0.4818, train_acc:0.8318
# epoch:10 testing: test_seq_acc:0.483, test_seq_auc:0.8409, test_video_acc:0.483, test_video_auc:0.8409
# epoch:10 summary: best_seq_acc:0.5531 best_seq_auc:0.8677 best_video_acc:0.5531 best_video_auc:0.8677
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:11 training: emb_loss:0.08941 clf_loss:0.4658, loss:0.4748, train_acc:0.8382
# epoch:11 testing: test_seq_acc:0.541, test_seq_auc:0.8443, test_video_acc:0.541, test_video_auc:0.8443
# epoch:11 summary: best_seq_acc:0.5531 best_seq_auc:0.8677 best_video_acc:0.5531 best_video_auc:0.8677
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:12 training: emb_loss:0.07777 clf_loss:0.4573, loss:0.4651, train_acc:0.8506save the model to ./weights/torch/test.pth
# epoch:12 testing: test_seq_acc:0.5601, test_seq_auc:0.8892, test_video_acc:0.5601, test_video_auc:0.8892save the model to ./weights/torch/test.pth
# epoch:12 summary: best_seq_acc:0.5601 best_seq_auc:0.8892 best_video_acc:0.5601 best_video_auc:0.8892save the model to ./weights/torch/test.pth
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:13 training: emb_loss:0.07809 clf_loss:0.4546, loss:0.4624, train_acc:0.8498save the model to ./weights/torch/test.pth
# epoch:13 testing: test_seq_acc:0.6632, test_seq_auc:0.8921, test_video_acc:0.6632, test_video_auc:0.8921save the model to ./weights/torch/test.pth
# epoch:13 summary: best_seq_acc:0.6632 best_seq_auc:0.8921 best_video_acc:0.6632 best_video_auc:0.8921save the model to ./weights/torch/test.pth
# ***************************************************************************************************
# ***************************************************************************************************
# epoch:14 training: emb_loss:0.07202 clf_loss:0.4432, loss:0.4504, train_acc:0.8638save the model to ./weights/torch/test.pth
# epoch:14 testing: test_seq_acc:0.6722, test_seq_auc:0.891, test_video_acc:0.6722, test_video_auc:0.891save the model to ./weights/torch/test.pth
# epoch:14 summary: best_seq_acc:0.6722 best_seq_auc:0.8921 best_video_acc:0.6722 best_video_auc:0.8921save the model to ./weights/torch/test.pth
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:15 training: emb_loss:0.07112 clf_loss:0.4427, loss:0.4498, train_acc:0.8632save the model to ./weights/torch/test.pth
# epoch:15 testing: test_seq_acc:0.7032, test_seq_auc:0.9107, test_video_acc:0.7032, test_video_auc:0.9107save the model to ./weights/torch/test.pth
# epoch:15 summary: best_seq_acc:0.7032 best_seq_auc:0.9107 best_video_acc:0.7032 best_video_auc:0.9107save the model to ./weights/torch/test.pth
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:16 training: emb_loss:0.06543 clf_loss:0.4339, loss:0.4405, train_acc:0.8734
# epoch:16 testing: test_seq_acc:0.5035, test_seq_auc:0.9204, test_video_acc:0.5035, test_video_auc:0.9204
# epoch:16 summary: best_seq_acc:0.7032 best_seq_auc:0.9204 best_video_acc:0.7032 best_video_auc:0.9204
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:17 training: emb_loss:0.06461 clf_loss:0.4343, loss:0.4408, train_acc:0.8742
# epoch:17 testing: test_seq_acc:0.6892, test_seq_auc:0.929, test_video_acc:0.6892, test_video_auc:0.929
# epoch:17 summary: best_seq_acc:0.7032 best_seq_auc:0.929 best_video_acc:0.7032 best_video_auc:0.929
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:18 training: emb_loss:0.06132 clf_loss:0.4264, loss:0.4325, train_acc:0.8833save the model to ./weights/torch/test.pth
# epoch:18 testing: test_seq_acc:0.7878, test_seq_auc:0.9385, test_video_acc:0.7878, test_video_auc:0.9385save the model to ./weights/torch/test.pth
# epoch:18 summary: best_seq_acc:0.7878 best_seq_auc:0.9385 best_video_acc:0.7878 best_video_auc:0.9385save the model to ./weights/torch/test.pth
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:19 training: emb_loss:0.05671 clf_loss:0.4234, loss:0.429, train_acc:0.8861
# epoch:19 testing: test_seq_acc:0.6336, test_seq_auc:0.9417, test_video_acc:0.6336, test_video_auc:0.9417
# epoch:19 summary: best_seq_acc:0.7878 best_seq_auc:0.9417 best_video_acc:0.7878 best_video_auc:0.9417
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:20 training: emb_loss:0.05267 clf_loss:0.4226, loss:0.4278, train_acc:0.8863
# epoch:20 testing: test_seq_acc:0.6782, test_seq_auc:0.9156, test_video_acc:0.6782, test_video_auc:0.9156
# epoch:20 summary: best_seq_acc:0.7878 best_seq_auc:0.9417 best_video_acc:0.7878 best_video_auc:0.9417
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:21 training: emb_loss:0.04196 clf_loss:0.4165, loss:0.4207, train_acc:0.8933
# epoch:21 testing: test_seq_acc:0.7232, test_seq_auc:0.9108, test_video_acc:0.7232, test_video_auc:0.9108
# epoch:21 summary: best_seq_acc:0.7878 best_seq_auc:0.9417 best_video_acc:0.7878 best_video_auc:0.9417
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:22 training: emb_loss:0.0443 clf_loss:0.4124, loss:0.4168, train_acc:0.8985
# epoch:22 testing: test_seq_acc:0.6592, test_seq_auc:0.9137, test_video_acc:0.6592, test_video_auc:0.9137
# epoch:22 summary: best_seq_acc:0.7878 best_seq_auc:0.9417 best_video_acc:0.7878 best_video_auc:0.9417
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:23 training: emb_loss:0.04408 clf_loss:0.4135, loss:0.4179, train_acc:0.8956
# epoch:23 testing: test_seq_acc:0.6732, test_seq_auc:0.9379, test_video_acc:0.6732, test_video_auc:0.9379
# epoch:23 summary: best_seq_acc:0.7878 best_seq_auc:0.9417 best_video_acc:0.7878 best_video_auc:0.9417
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:24 training: emb_loss:0.04132 clf_loss:0.4078, loss:0.4119, train_acc:0.9016
# epoch:24 testing: test_seq_acc:0.7112, test_seq_auc:0.9527, test_video_acc:0.7112, test_video_auc:0.9527
# epoch:24 summary: best_seq_acc:0.7878 best_seq_auc:0.9527 best_video_acc:0.7878 best_video_auc:0.9527
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:25 training: emb_loss:0.04049 clf_loss:0.4069, loss:0.411, train_acc:0.9023save the model to ./weights/torch/test.pth
# epoch:25 testing: test_seq_acc:0.8819, test_seq_auc:0.9346, test_video_acc:0.8819, test_video_auc:0.9346save the model to ./weights/torch/test.pth
# epoch:25 summary: best_seq_acc:0.8819 best_seq_auc:0.9527 best_video_acc:0.8819 best_video_auc:0.9527save the model to ./weights/torch/test.pth
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:26 training: emb_loss:0.04348 clf_loss:0.403, loss:0.4073, train_acc:0.9069
# epoch:26 testing: test_seq_acc:0.7392, test_seq_auc:0.9318, test_video_acc:0.7392, test_video_auc:0.9318
# epoch:26 summary: best_seq_acc:0.8819 best_seq_auc:0.9527 best_video_acc:0.8819 best_video_auc:0.9527
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:27 training: emb_loss:0.04057 clf_loss:0.4029, loss:0.407, train_acc:0.9067
# epoch:27 testing: test_seq_acc:0.6261, test_seq_auc:0.9305, test_video_acc:0.6261, test_video_auc:0.9305
# epoch:27 summary: best_seq_acc:0.8819 best_seq_auc:0.9527 best_video_acc:0.8819 best_video_auc:0.9527
# ***************************************************************************************************
# ***************************************************************************************************
# epoch:28 training: emb_loss:0.03811 clf_loss:0.405, loss:0.4088, train_acc:0.9042save the model to ./weights/torch/test.pth
# epoch:28 testing: test_seq_acc:0.9014, test_seq_auc:0.9519, test_video_acc:0.9014, test_video_auc:0.9519save the model to ./weights/torch/test.pth
# epoch:28 summary: best_seq_acc:0.9014 best_seq_auc:0.9527 best_video_acc:0.9014 best_video_auc:0.9527save the model to ./weights/torch/test.pth
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:29 training: emb_loss:0.03629 clf_loss:0.4006, loss:0.4043, train_acc:0.9088
# epoch:29 testing: test_seq_acc:0.8764, test_seq_auc:0.934, test_video_acc:0.8764, test_video_auc:0.934
# epoch:29 summary: best_seq_acc:0.9014 best_seq_auc:0.9527 best_video_acc:0.9014 best_video_auc:0.9527
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:30 training: emb_loss:0.03097 clf_loss:0.3957, loss:0.3988, train_acc:0.9144
# epoch:30 testing: test_seq_acc:0.6792, test_seq_auc:0.9506, test_video_acc:0.6792, test_video_auc:0.9506
# epoch:30 summary: best_seq_acc:0.9014 best_seq_auc:0.9527 best_video_acc:0.9014 best_video_auc:0.9527
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:31 training: emb_loss:0.03434 clf_loss:0.3944, loss:0.3979, train_acc:0.9147
# epoch:31 testing: test_seq_acc:0.7487, test_seq_auc:0.9324, test_video_acc:0.7487, test_video_auc:0.9324
# epoch:31 summary: best_seq_acc:0.9014 best_seq_auc:0.9527 best_video_acc:0.9014 best_video_auc:0.9527
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:32 training: emb_loss:0.02976 clf_loss:0.3908, loss:0.3938, train_acc:0.9184
# epoch:32 testing: test_seq_acc:0.8158, test_seq_auc:0.909, test_video_acc:0.8158, test_video_auc:0.909
# epoch:32 summary: best_seq_acc:0.9014 best_seq_auc:0.9527 best_video_acc:0.9014 best_video_auc:0.9527
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:33 training: emb_loss:0.04096 clf_loss:0.3967, loss:0.4008, train_acc:0.9125
# epoch:33 testing: test_seq_acc:0.6952, test_seq_auc:0.9417, test_video_acc:0.6952, test_video_auc:0.9417
# epoch:33 summary: best_seq_acc:0.9014 best_seq_auc:0.9527 best_video_acc:0.9014 best_video_auc:0.9527
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:34 training: emb_loss:0.03427 clf_loss:0.3912, loss:0.3946, train_acc:0.9197
# epoch:34 testing: test_seq_acc:0.8769, test_seq_auc:0.9357, test_video_acc:0.8769, test_video_auc:0.9357
# epoch:34 summary: best_seq_acc:0.9014 best_seq_auc:0.9527 best_video_acc:0.9014 best_video_auc:0.9527
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:35 training: emb_loss:0.03762 clf_loss:0.3903, loss:0.394, train_acc:0.9195
# epoch:35 testing: test_seq_acc:0.7978, test_seq_auc:0.9295, test_video_acc:0.7978, test_video_auc:0.9295
# epoch:35 summary: best_seq_acc:0.9014 best_seq_auc:0.9527 best_video_acc:0.9014 best_video_auc:0.9527
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:36 training: emb_loss:0.0361 clf_loss:0.3878, loss:0.3914, train_acc:0.9208save the model to ./weights/torch/test.pth
# epoch:36 testing: test_seq_acc:0.9219, test_seq_auc:0.951, test_video_acc:0.9219, test_video_auc:0.951save the model to ./weights/torch/test.pth
# epoch:36 summary: best_seq_acc:0.9219 best_seq_auc:0.9527 best_video_acc:0.9219 best_video_auc:0.9527save the model to ./weights/torch/test.pth
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:37 training: emb_loss:0.03181 clf_loss:0.3869, loss:0.3901, train_acc:0.9236
# epoch:37 testing: test_seq_acc:0.6867, test_seq_auc:0.954, test_video_acc:0.6867, test_video_auc:0.954
# epoch:37 summary: best_seq_acc:0.9219 best_seq_auc:0.954 best_video_acc:0.9219 best_video_auc:0.954
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:38 training: emb_loss:0.02263 clf_loss:0.3823, loss:0.3846, train_acc:0.9283
# epoch:38 testing: test_seq_acc:0.9034, test_seq_auc:0.9369, test_video_acc:0.9034, test_video_auc:0.9369
# epoch:38 summary: best_seq_acc:0.9219 best_seq_auc:0.954 best_video_acc:0.9219 best_video_auc:0.954
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:39 training: emb_loss:0.02672 clf_loss:0.3851, loss:0.3877, train_acc:0.9251
# epoch:39 testing: test_seq_acc:0.7302, test_seq_auc:0.9495, test_video_acc:0.7302, test_video_auc:0.9495
# epoch:39 summary: best_seq_acc:0.9219 best_seq_auc:0.954 best_video_acc:0.9219 best_video_auc:0.954
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:40 training: emb_loss:0.02569 clf_loss:0.3826, loss:0.3852, train_acc:0.9285
# epoch:40 testing: test_seq_acc:0.8864, test_seq_auc:0.9563, test_video_acc:0.8864, test_video_auc:0.9563
# epoch:40 summary: best_seq_acc:0.9219 best_seq_auc:0.9563 best_video_acc:0.9219 best_video_auc:0.9563
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:41 training: emb_loss:0.02719 clf_loss:0.3824, loss:0.3851, train_acc:0.9289
# epoch:41 testing: test_seq_acc:0.7738, test_seq_auc:0.948, test_video_acc:0.7738, test_video_auc:0.948
# epoch:41 summary: best_seq_acc:0.9219 best_seq_auc:0.9563 best_video_acc:0.9219 best_video_auc:0.9563
# ***************************************************************************************************
# ***************************************************************************************************
# epoch:42 training: emb_loss:0.02134 clf_loss:0.3794, loss:0.3816, train_acc:0.9308
# epoch:42 testing: test_seq_acc:0.8043, test_seq_auc:0.9577, test_video_acc:0.8043, test_video_auc:0.9577
# epoch:42 summary: best_seq_acc:0.9219 best_seq_auc:0.9577 best_video_acc:0.9219 best_video_auc:0.9577
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:43 training: emb_loss:0.02493 clf_loss:0.3781, loss:0.3806, train_acc:0.9315
# epoch:43 testing: test_seq_acc:0.9124, test_seq_auc:0.9493, test_video_acc:0.9124, test_video_auc:0.9493
# epoch:43 summary: best_seq_acc:0.9219 best_seq_auc:0.9577 best_video_acc:0.9219 best_video_auc:0.9577
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:44 training: emb_loss:0.02649 clf_loss:0.3778, loss:0.3804, train_acc:0.9328
# epoch:44 testing: test_seq_acc:0.8834, test_seq_auc:0.962, test_video_acc:0.8834, test_video_auc:0.962
# epoch:44 summary: best_seq_acc:0.9219 best_seq_auc:0.962 best_video_acc:0.9219 best_video_auc:0.962
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:45 training: emb_loss:0.02262 clf_loss:0.3776, loss:0.3798, train_acc:0.9315
# epoch:45 testing: test_seq_acc:0.8959, test_seq_auc:0.9407, test_video_acc:0.8959, test_video_auc:0.9407
# epoch:45 summary: best_seq_acc:0.9219 best_seq_auc:0.962 best_video_acc:0.9219 best_video_auc:0.962
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:46 training: emb_loss:0.0206 clf_loss:0.3744, loss:0.3765, train_acc:0.9372
# epoch:46 testing: test_seq_acc:0.8448, test_seq_auc:0.9509, test_video_acc:0.8448, test_video_auc:0.9509
# epoch:46 summary: best_seq_acc:0.9219 best_seq_auc:0.962 best_video_acc:0.9219 best_video_auc:0.962
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:47 training: emb_loss:0.02221 clf_loss:0.3742, loss:0.3764, train_acc:0.9358save the model to ./weights/torch/test.pth
# epoch:47 testing: test_seq_acc:0.9505, test_seq_auc:0.9614, test_video_acc:0.9505, test_video_auc:0.9614save the model to ./weights/torch/test.pth
# epoch:47 summary: best_seq_acc:0.9505 best_seq_auc:0.962 best_video_acc:0.9505 best_video_auc:0.962save the model to ./weights/torch/test.pth
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:48 training: emb_loss:0.02331 clf_loss:0.375, loss:0.3773, train_acc:0.936
# epoch:48 testing: test_seq_acc:0.9024, test_seq_auc:0.9642, test_video_acc:0.9024, test_video_auc:0.9642
# epoch:48 summary: best_seq_acc:0.9505 best_seq_auc:0.9642 best_video_acc:0.9505 best_video_auc:0.9642
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:49 training: emb_loss:0.02133 clf_loss:0.3768, loss:0.3789, train_acc:0.934
# epoch:49 testing: test_seq_acc:0.8789, test_seq_auc:0.9523, test_video_acc:0.8789, test_video_auc:0.9523
# epoch:49 summary: best_seq_acc:0.9505 best_seq_auc:0.9642 best_video_acc:0.9505 best_video_auc:0.9642
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:50 training: emb_loss:0.01863 clf_loss:0.3729, loss:0.3748, train_acc:0.9384
# epoch:50 testing: test_seq_acc:0.8654, test_seq_auc:0.9517, test_video_acc:0.8654, test_video_auc:0.9517
# epoch:50 summary: best_seq_acc:0.9505 best_seq_auc:0.9642 best_video_acc:0.9505 best_video_auc:0.9642
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:51 training: emb_loss:0.02263 clf_loss:0.373, loss:0.3753, train_acc:0.9383
# epoch:51 testing: test_seq_acc:0.6857, test_seq_auc:0.9502, test_video_acc:0.6857, test_video_auc:0.9502
# epoch:51 summary: best_seq_acc:0.9505 best_seq_auc:0.9642 best_video_acc:0.9505 best_video_auc:0.9642
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:52 training: emb_loss:0.02347 clf_loss:0.3703, loss:0.3726, train_acc:0.9414
# epoch:52 testing: test_seq_acc:0.7548, test_seq_auc:0.9489, test_video_acc:0.7548, test_video_auc:0.9489
# epoch:52 summary: best_seq_acc:0.9505 best_seq_auc:0.9642 best_video_acc:0.9505 best_video_auc:0.9642
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:53 training: emb_loss:0.01983 clf_loss:0.3714, loss:0.3733, train_acc:0.9401
# epoch:53 testing: test_seq_acc:0.8969, test_seq_auc:0.952, test_video_acc:0.8969, test_video_auc:0.952
# epoch:53 summary: best_seq_acc:0.9505 best_seq_auc:0.9642 best_video_acc:0.9505 best_video_auc:0.9642
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:54 training: emb_loss:0.01458 clf_loss:0.3676, loss:0.3691, train_acc:0.9434
# epoch:54 testing: test_seq_acc:0.8333, test_seq_auc:0.9601, test_video_acc:0.8333, test_video_auc:0.9601
# epoch:54 summary: best_seq_acc:0.9505 best_seq_auc:0.9642 best_video_acc:0.9505 best_video_auc:0.9642
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:55 training: emb_loss:0.02563 clf_loss:0.3666, loss:0.3691, train_acc:0.9446
# epoch:55 testing: test_seq_acc:0.8999, test_seq_auc:0.9557, test_video_acc:0.8999, test_video_auc:0.9557
# epoch:55 summary: best_seq_acc:0.9505 best_seq_auc:0.9642 best_video_acc:0.9505 best_video_auc:0.9642
# ***************************************************************************************************
# ***************************************************************************************************
# epoch:56 training: emb_loss:0.01896 clf_loss:0.369, loss:0.3709, train_acc:0.9415
# epoch:56 testing: test_seq_acc:0.8804, test_seq_auc:0.9615, test_video_acc:0.8804, test_video_auc:0.9615
# epoch:56 summary: best_seq_acc:0.9505 best_seq_auc:0.9642 best_video_acc:0.9505 best_video_auc:0.9642
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:57 training: emb_loss:0.02237 clf_loss:0.3684, loss:0.3706, train_acc:0.9435
# epoch:57 testing: test_seq_acc:0.9024, test_seq_auc:0.9531, test_video_acc:0.9024, test_video_auc:0.9531
# epoch:57 summary: best_seq_acc:0.9505 best_seq_auc:0.9642 best_video_acc:0.9505 best_video_auc:0.9642
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:58 training: emb_loss:0.01523 clf_loss:0.3657, loss:0.3672, train_acc:0.9447
# epoch:58 testing: test_seq_acc:0.8148, test_seq_auc:0.944, test_video_acc:0.8148, test_video_auc:0.944
# epoch:58 summary: best_seq_acc:0.9505 best_seq_auc:0.9642 best_video_acc:0.9505 best_video_auc:0.9642
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:59 training: emb_loss:0.02329 clf_loss:0.3669, loss:0.3692, train_acc:0.9435
# epoch:59 testing: test_seq_acc:0.8564, test_seq_auc:0.9596, test_video_acc:0.8564, test_video_auc:0.9596
# epoch:59 summary: best_seq_acc:0.9505 best_seq_auc:0.9642 best_video_acc:0.9505 best_video_auc:0.9642
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:60 training: emb_loss:0.01561 clf_loss:0.3663, loss:0.3679, train_acc:0.9452
# epoch:60 testing: test_seq_acc:0.7402, test_seq_auc:0.9513, test_video_acc:0.7402, test_video_auc:0.9513
# epoch:60 summary: best_seq_acc:0.9505 best_seq_auc:0.9642 best_video_acc:0.9505 best_video_auc:0.9642
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:61 training: emb_loss:0.01616 clf_loss:0.3624, loss:0.364, train_acc:0.9492
# epoch:61 testing: test_seq_acc:0.8358, test_seq_auc:0.9565, test_video_acc:0.8358, test_video_auc:0.9565
# epoch:61 summary: best_seq_acc:0.9505 best_seq_auc:0.9642 best_video_acc:0.9505 best_video_auc:0.9642
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:62 training: emb_loss:0.01612 clf_loss:0.3622, loss:0.3638, train_acc:0.9495
# epoch:62 testing: test_seq_acc:0.8644, test_seq_auc:0.9615, test_video_acc:0.8644, test_video_auc:0.9615
# epoch:62 summary: best_seq_acc:0.9505 best_seq_auc:0.9642 best_video_acc:0.9505 best_video_auc:0.9642
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:63 training: emb_loss:0.01522 clf_loss:0.3644, loss:0.3659, train_acc:0.9465
# epoch:63 testing: test_seq_acc:0.7743, test_seq_auc:0.963, test_video_acc:0.7743, test_video_auc:0.963
# epoch:63 summary: best_seq_acc:0.9505 best_seq_auc:0.9642 best_video_acc:0.9505 best_video_auc:0.9642
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:64 training: emb_loss:0.01508 clf_loss:0.3643, loss:0.3658, train_acc:0.9477
# epoch:64 testing: test_seq_acc:0.8849, test_seq_auc:0.9596, test_video_acc:0.8849, test_video_auc:0.9596
# epoch:64 summary: best_seq_acc:0.9505 best_seq_auc:0.9642 best_video_acc:0.9505 best_video_auc:0.9642
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:65 training: emb_loss:0.01439 clf_loss:0.3624, loss:0.3639, train_acc:0.9487
# epoch:65 testing: test_seq_acc:0.8418, test_seq_auc:0.9651, test_video_acc:0.8418, test_video_auc:0.9651
# epoch:65 summary: best_seq_acc:0.9505 best_seq_auc:0.9651 best_video_acc:0.9505 best_video_auc:0.9651
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:66 training: emb_loss:0.01541 clf_loss:0.3633, loss:0.3648, train_acc:0.9479
# epoch:66 testing: test_seq_acc:0.8048, test_seq_auc:0.9516, test_video_acc:0.8048, test_video_auc:0.9516
# epoch:66 summary: best_seq_acc:0.9505 best_seq_auc:0.9651 best_video_acc:0.9505 best_video_auc:0.9651
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:67 training: emb_loss:0.01729 clf_loss:0.3608, loss:0.3625, train_acc:0.9508
# epoch:67 testing: test_seq_acc:0.9024, test_seq_auc:0.9652, test_video_acc:0.9024, test_video_auc:0.9652
# epoch:67 summary: best_seq_acc:0.9505 best_seq_auc:0.9652 best_video_acc:0.9505 best_video_auc:0.9652
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:68 training: emb_loss:0.01808 clf_loss:0.3615, loss:0.3633, train_acc:0.9502
# epoch:68 testing: test_seq_acc:0.8148, test_seq_auc:0.9567, test_video_acc:0.8148, test_video_auc:0.9567
# epoch:68 summary: best_seq_acc:0.9505 best_seq_auc:0.9652 best_video_acc:0.9505 best_video_auc:0.9652
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:69 training: emb_loss:0.01497 clf_loss:0.361, loss:0.3625, train_acc:0.9511
# epoch:69 testing: test_seq_acc:0.8509, test_seq_auc:0.9401, test_video_acc:0.8509, test_video_auc:0.9401
# epoch:69 summary: best_seq_acc:0.9505 best_seq_auc:0.9652 best_video_acc:0.9505 best_video_auc:0.9652
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:70 training: emb_loss:0.01337 clf_loss:0.357, loss:0.3584, train_acc:0.9543
# epoch:70 testing: test_seq_acc:0.7668, test_seq_auc:0.9528, test_video_acc:0.7668, test_video_auc:0.9528
# epoch:70 summary: best_seq_acc:0.9505 best_seq_auc:0.9652 best_video_acc:0.9505 best_video_auc:0.9652
# ***************************************************************************************************
# ***************************************************************************************************
# epoch:71 training: emb_loss:0.01308 clf_loss:0.3593, loss:0.3606, train_acc:0.951
# epoch:71 testing: test_seq_acc:0.7247, test_seq_auc:0.9608, test_video_acc:0.7247, test_video_auc:0.9608
# epoch:71 summary: best_seq_acc:0.9505 best_seq_auc:0.9652 best_video_acc:0.9505 best_video_auc:0.9652
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:72 training: emb_loss:0.01322 clf_loss:0.3604, loss:0.3617, train_acc:0.9516
# epoch:72 testing: test_seq_acc:0.8619, test_seq_auc:0.942, test_video_acc:0.8619, test_video_auc:0.942
# epoch:72 summary: best_seq_acc:0.9505 best_seq_auc:0.9652 best_video_acc:0.9505 best_video_auc:0.9652
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:73 training: emb_loss:0.01888 clf_loss:0.3608, loss:0.3626, train_acc:0.9516
# epoch:73 testing: test_seq_acc:0.6632, test_seq_auc:0.9084, test_video_acc:0.6632, test_video_auc:0.9084
# epoch:73 summary: best_seq_acc:0.9505 best_seq_auc:0.9652 best_video_acc:0.9505 best_video_auc:0.9652
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:74 training: emb_loss:0.009338 clf_loss:0.3598, loss:0.3607, train_acc:0.9517
# epoch:74 testing: test_seq_acc:0.8068, test_seq_auc:0.962, test_video_acc:0.8068, test_video_auc:0.962
# epoch:74 summary: best_seq_acc:0.9505 best_seq_auc:0.9652 best_video_acc:0.9505 best_video_auc:0.9652
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:75 training: emb_loss:0.00938 clf_loss:0.3596, loss:0.3605, train_acc:0.951
# epoch:75 testing: test_seq_acc:0.8168, test_seq_auc:0.9478, test_video_acc:0.8168, test_video_auc:0.9478
# epoch:75 summary: best_seq_acc:0.9505 best_seq_auc:0.9652 best_video_acc:0.9505 best_video_auc:0.9652
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:76 training: emb_loss:0.01328 clf_loss:0.357, loss:0.3583, train_acc:0.9544
# epoch:76 testing: test_seq_acc:0.8438, test_seq_auc:0.9579, test_video_acc:0.8438, test_video_auc:0.9579
# epoch:76 summary: best_seq_acc:0.9505 best_seq_auc:0.9652 best_video_acc:0.9505 best_video_auc:0.9652
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:77 training: emb_loss:0.0128 clf_loss:0.3591, loss:0.3604, train_acc:0.9532
# epoch:77 testing: test_seq_acc:0.9099, test_seq_auc:0.948, test_video_acc:0.9099, test_video_auc:0.948
# epoch:77 summary: best_seq_acc:0.9505 best_seq_auc:0.9652 best_video_acc:0.9505 best_video_auc:0.9652
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:78 training: emb_loss:0.01158 clf_loss:0.3545, loss:0.3557, train_acc:0.9576
# epoch:78 testing: test_seq_acc:0.8589, test_seq_auc:0.9522, test_video_acc:0.8589, test_video_auc:0.9522
# epoch:78 summary: best_seq_acc:0.9505 best_seq_auc:0.9652 best_video_acc:0.9505 best_video_auc:0.9652
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:79 training: emb_loss:0.01265 clf_loss:0.353, loss:0.3542, train_acc:0.9592
# epoch:79 testing: test_seq_acc:0.8313, test_seq_auc:0.9612, test_video_acc:0.8313, test_video_auc:0.9612
# epoch:79 summary: best_seq_acc:0.9505 best_seq_auc:0.9652 best_video_acc:0.9505 best_video_auc:0.9652
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:80 training: emb_loss:0.01548 clf_loss:0.3608, loss:0.3623, train_acc:0.9499
# epoch:80 testing: test_seq_acc:0.9094, test_seq_auc:0.9537, test_video_acc:0.9094, test_video_auc:0.9537
# epoch:80 summary: best_seq_acc:0.9505 best_seq_auc:0.9652 best_video_acc:0.9505 best_video_auc:0.9652
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:81 training: emb_loss:0.01311 clf_loss:0.3558, loss:0.3571, train_acc:0.9561
# epoch:81 testing: test_seq_acc:0.9119, test_seq_auc:0.9626, test_video_acc:0.9119, test_video_auc:0.9626
# epoch:81 summary: best_seq_acc:0.9505 best_seq_auc:0.9652 best_video_acc:0.9505 best_video_auc:0.9652
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:82 training: emb_loss:0.01058 clf_loss:0.3547, loss:0.3557, train_acc:0.957
# epoch:82 testing: test_seq_acc:0.8859, test_seq_auc:0.9747, test_video_acc:0.8859, test_video_auc:0.9747
# epoch:82 summary: best_seq_acc:0.9505 best_seq_auc:0.9747 best_video_acc:0.9505 best_video_auc:0.9747
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:83 training: emb_loss:0.0128 clf_loss:0.3586, loss:0.3599, train_acc:0.9512
# epoch:83 testing: test_seq_acc:0.8614, test_seq_auc:0.9579, test_video_acc:0.8614, test_video_auc:0.9579
# epoch:83 summary: best_seq_acc:0.9505 best_seq_auc:0.9747 best_video_acc:0.9505 best_video_auc:0.9747
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:84 training: emb_loss:0.01016 clf_loss:0.3501, loss:0.3511, train_acc:0.9615
# epoch:84 testing: test_seq_acc:0.9019, test_seq_auc:0.9561, test_video_acc:0.9019, test_video_auc:0.9561
# epoch:84 summary: best_seq_acc:0.9505 best_seq_auc:0.9747 best_video_acc:0.9505 best_video_auc:0.9747
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:85 training: emb_loss:0.01081 clf_loss:0.3542, loss:0.3553, train_acc:0.9573
# epoch:85 testing: test_seq_acc:0.8584, test_seq_auc:0.9612, test_video_acc:0.8584, test_video_auc:0.9612
# epoch:85 summary: best_seq_acc:0.9505 best_seq_auc:0.9747 best_video_acc:0.9505 best_video_auc:0.9747
# ***************************************************************************************************
# ***************************************************************************************************
# epoch:86 training: emb_loss:0.009915 clf_loss:0.3534, loss:0.3544, train_acc:0.958
# epoch:86 testing: test_seq_acc:0.7973, test_seq_auc:0.9704, test_video_acc:0.7973, test_video_auc:0.9704
# epoch:86 summary: best_seq_acc:0.9505 best_seq_auc:0.9747 best_video_acc:0.9505 best_video_auc:0.9747
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:87 training: emb_loss:0.008228 clf_loss:0.3522, loss:0.353, train_acc:0.9602
# epoch:87 testing: test_seq_acc:0.8428, test_seq_auc:0.9677, test_video_acc:0.8428, test_video_auc:0.9677
# epoch:87 summary: best_seq_acc:0.9505 best_seq_auc:0.9747 best_video_acc:0.9505 best_video_auc:0.9747
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:88 training: emb_loss:0.00736 clf_loss:0.3503, loss:0.351, train_acc:0.9616
# epoch:88 testing: test_seq_acc:0.8884, test_seq_auc:0.96, test_video_acc:0.8884, test_video_auc:0.96
# epoch:88 summary: best_seq_acc:0.9505 best_seq_auc:0.9747 best_video_acc:0.9505 best_video_auc:0.9747
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:89 training: emb_loss:0.009519 clf_loss:0.349, loss:0.3499, train_acc:0.9632
# epoch:89 testing: test_seq_acc:0.8629, test_seq_auc:0.9496, test_video_acc:0.8629, test_video_auc:0.9496
# epoch:89 summary: best_seq_acc:0.9505 best_seq_auc:0.9747 best_video_acc:0.9505 best_video_auc:0.9747
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:90 training: emb_loss:0.01309 clf_loss:0.3534, loss:0.3547, train_acc:0.9584
# epoch:90 testing: test_seq_acc:0.8108, test_seq_auc:0.9547, test_video_acc:0.8108, test_video_auc:0.9547
# epoch:90 summary: best_seq_acc:0.9505 best_seq_auc:0.9747 best_video_acc:0.9505 best_video_auc:0.9747
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:91 training: emb_loss:0.008873 clf_loss:0.3509, loss:0.3518, train_acc:0.9603
# epoch:91 testing: test_seq_acc:0.8463, test_seq_auc:0.9555, test_video_acc:0.8463, test_video_auc:0.9555
# epoch:91 summary: best_seq_acc:0.9505 best_seq_auc:0.9747 best_video_acc:0.9505 best_video_auc:0.9747
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:92 training: emb_loss:0.0069 clf_loss:0.3488, loss:0.3495, train_acc:0.9625
# epoch:92 testing: test_seq_acc:0.9029, test_seq_auc:0.9536, test_video_acc:0.9029, test_video_auc:0.9536
# epoch:92 summary: best_seq_acc:0.9505 best_seq_auc:0.9747 best_video_acc:0.9505 best_video_auc:0.9747
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:93 training: emb_loss:0.008177 clf_loss:0.3504, loss:0.3512, train_acc:0.9608
# epoch:93 testing: test_seq_acc:0.8373, test_seq_auc:0.9515, test_video_acc:0.8373, test_video_auc:0.9515
# epoch:93 summary: best_seq_acc:0.9505 best_seq_auc:0.9747 best_video_acc:0.9505 best_video_auc:0.9747
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:94 training: emb_loss:0.0104 clf_loss:0.3525, loss:0.3536, train_acc:0.9583
# epoch:94 testing: test_seq_acc:0.7377, test_seq_auc:0.9231, test_video_acc:0.7377, test_video_auc:0.9231
# epoch:94 summary: best_seq_acc:0.9505 best_seq_auc:0.9747 best_video_acc:0.9505 best_video_auc:0.9747
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:95 training: emb_loss:0.01002 clf_loss:0.3487, loss:0.3497, train_acc:0.9622
# epoch:95 testing: test_seq_acc:0.7848, test_seq_auc:0.9587, test_video_acc:0.7848, test_video_auc:0.9587
# epoch:95 summary: best_seq_acc:0.9505 best_seq_auc:0.9747 best_video_acc:0.9505 best_video_auc:0.9747
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:96 training: emb_loss:0.008743 clf_loss:0.3529, loss:0.3538, train_acc:0.9593
# epoch:96 testing: test_seq_acc:0.8388, test_seq_auc:0.9512, test_video_acc:0.8388, test_video_auc:0.9512
# epoch:96 summary: best_seq_acc:0.9505 best_seq_auc:0.9747 best_video_acc:0.9505 best_video_auc:0.9747
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:97 training: emb_loss:0.009148 clf_loss:0.3491, loss:0.35, train_acc:0.9627
# epoch:97 testing: test_seq_acc:0.8168, test_seq_auc:0.9623, test_video_acc:0.8168, test_video_auc:0.9623
# epoch:97 summary: best_seq_acc:0.9505 best_seq_auc:0.9747 best_video_acc:0.9505 best_video_auc:0.9747
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:98 training: emb_loss:0.01038 clf_loss:0.3498, loss:0.3509, train_acc:0.9614
# epoch:98 testing: test_seq_acc:0.8604, test_seq_auc:0.9436, test_video_acc:0.8604, test_video_auc:0.9436
# epoch:98 summary: best_seq_acc:0.9505 best_seq_auc:0.9747 best_video_acc:0.9505 best_video_auc:0.9747
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:99 training: emb_loss:0.01133 clf_loss:0.3495, loss:0.3506, train_acc:0.9634
# epoch:99 testing: test_seq_acc:0.9294, test_seq_auc:0.9638, test_video_acc:0.9294, test_video_auc:0.9638
# epoch:99 summary: best_seq_acc:0.9505 best_seq_auc:0.9747 best_video_acc:0.9505 best_video_auc:0.9747
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:100 training: emb_loss:0.01093 clf_loss:0.3487, loss:0.3498, train_acc:0.9634
# epoch:100 testing: test_seq_acc:0.8839, test_seq_auc:0.9746, test_video_acc:0.8839, test_video_auc:0.9746
# epoch:100 summary: best_seq_acc:0.9505 best_seq_auc:0.9747 best_video_acc:0.9505 best_video_auc:0.9747
# ***************************************************************************************************
#
#
# 100%|█████████████████████████████████████████| 100/100 [24:28<00:00, 14.69s/it]

# %% [markdown]
# # 3. TI2Net evaluation

# %%
# !python evaluate.py \
--model="test.pth" \
--real_id_path="./id_vectors/FFpp/ffpp_real_ids_test.npy" \
--real_len_path="./id_vectors/FFpp/ffpp_real_lens_test.npy" \
--fake_id_path="./id_vectors/FFpp/ffpp_fake_ids_test.npy" \
--fake_len_path="./id_vectors/FFpp/ffpp_fake_lens_test.npy"
# Out:
# Using device: cuda:0
# Please register the status.
#
#
# #----Evaluation Results----#
# Accuracy (sequence-level): 0.99
# AUC (sequence-level): 0.998
# Accuracy (video-level): 0.99
# AUC (video-level): 0.998
# #------------End-----------#
