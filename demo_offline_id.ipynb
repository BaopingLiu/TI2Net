# %% [markdown]
# # 1. identity extraction

# %%
import os
import argparse
import numpy as np 
from tqdm import  tqdm
from glob import glob
from utils.libs import load_image, get_frame_id
from config.config import Config
from torch.nn import DataParallel
from models import resnet_face18
import torch
import cv2
torch.cuda.empty_cache()

test_model_path= "./pretrained/resnet18_110.pth"
opt = Config()
model = resnet_face18(opt.use_se)
model = DataParallel(model)
model.load_state_dict(torch.load(test_model_path))
model.to(torch.device("cuda"))
model.eval()

def video_id_extraction(path, 
                        save, 
                        len_save, 
                        batch_size = 16,
                        compress=None, 
                        noise=None):
    whole_set_ids = None
    video_length = []
    video_list = glob(path+"/*")
    video_list.sort()
    for video in tqdm(video_list):
        batch_frames = None
        video_ids = None
        batch_count = 0
        video_frames = glob(video+"/*")
        if len(glob(video+"/*")) < 1:
          print("empty folder", video)
          continue
        frame_list = glob(video+"/*")
        for frame in frame_list:
            batch_count += 1
            try:
             single_image = load_image(frame, compress=compress, noise=noise)
            except Exception as e:
              print("blocked-", frame)
              print("error-",e)
              del e
              continue
            if batch_frames is None:
                batch_frames = single_image
            else:
                batch_frames = np.concatenate((batch_frames, single_image), axis=0)
            if not batch_count % batch_size or batch_count==len(video_frames):
                batch_ids = get_frame_id(model, batch_frames, batch_size=batch_size)
                batch_frames = None
                if video_ids is None:
                    video_ids = batch_ids
                else:
                    video_len1 = video_ids.shape[0]
                    video_ids = np.concatenate((video_ids, batch_ids), axis=0)
        if whole_set_ids is None:
            whole_set_ids = video_ids
        else:
            whole_set_ids = np.concatenate((whole_set_ids, video_ids), axis=0)
        video_length.append(len(video_frames))
    video_length = np.array(video_length) 
    print("video_length", sum(video_length))
    print("whole_set_ids", len(whole_set_ids))
    np.save(save, whole_set_ids)
    np.save(len_save,video_length)
    del whole_set_ids, video_length

# %% [markdown]
# ### 1.1. FaceForensics++  dataset

# %%
save_root = "./id_vectors/FFpp/"

paths=["/home/baoping/FaceForensics++/manipulated_sequences/NeuralTextures/raw/aligned_faces", \
       "/home/baoping/FaceForensics++/manipulated_sequences/FaceSwap/raw/aligned_faces", \
       "/home/baoping/FaceForensics++/manipulated_sequences/Face2Face/raw/aligned_faces", \
       "/home/baoping/FaceForensics++/manipulated_sequences/Deepfakes/raw/aligned_faces", \
       "/home/baoping/FaceForensics++/original_sequences/youtube/raw/aligned_faces"  ]

ids_save_path = ["ffpp_nt_ids.npy", "ffpp_fs_ids.npy", "ffpp_ff_ids.npy", "ffpp_df_ids.npy", "ffpp_real_ids.npy"]#
len_save_path = ["ffpp_nt_lens.npy", "ffpp_fs_lens.npy", "ffpp_ff_lens.npy", "ffpp_df_lens.npy", "ffpp_real_lens.npy"]#
for idx, p in enumerate(paths):
    video_id_extraction(p, 
                        os.path.join( ids_save_path[idx] ), 
                        os.path.join( len_save_path[idx]) )

# %%
#merge several fake datasets
import numpy as np
import os

def set_merge(fake_id_list, real_length):
    fake_type_count = len(fake_id_list)
    real_video_count = real_length
    fake_video_count = int(real_video_count // fake_type_count)
    print("video count", real_video_count, fake_video_count)
    ret_list = []
    for i in fake_id_list:
        ret_list += i[:fake_video_count]
    return ret_list
ffpp_real_ids = "./id_vectors/FFpp/ffpp_real_ids.npy"
ffpp_real_len = "./id_vectors/FFpp/ffpp_real_lens.npy"
ffpp_df_ids = "./id_vectors/FFpp/ffpp_df_ids.npy"
ffpp_df_len = "./id_vectors/FFpp/ffpp_df_lens.npy"
ffpp_ff_ids = "./id_vectors/FFpp/ffpp_ff_ids.npy"
ffpp_ff_len = "./id_vectors/FFpp/ffpp_ff_lens.npy"
ffpp_fs_ids = "./id_vectors/FFpp/ffpp_fs_ids.npy"
ffpp_fs_len = "./id_vectors/FFpp/ffpp_fs_lens.npy"
ffpp_nt_ids = "./id_vectors/FFpp/ffpp_nt_ids.npy"
ffpp_nt_len = "./id_vectors/FFpp/ffpp_nt_lens.npy"

fake_ids_list = [ffpp_df_ids, ffpp_ff_ids, ffpp_fs_ids, ffpp_nt_ids]
fake_len_list = [ffpp_df_len, ffpp_ff_len, ffpp_fs_len, ffpp_nt_len]

real_ids = np.load(ffpp_real_ids)
real_len = np.load(ffpp_real_len, allow_pickle=True)
print("real shapes", real_ids.shape, real_len.shape)

merged_ids = None
merged_len = None
for i,l in zip(fake_ids_list,fake_len_list):#range(4):
    fake_ids = np.load(i)
    fake_len = np.load(l, allow_pickle=True)
    if merged_ids is None:
        merged_ids = fake_ids
        merged_len = fake_len
    else:
        merged_ids = np.concatenate((merged_ids,fake_ids))
        merged_len = np.concatenate((merged_len,fake_len))

np.save("./id_vectors/FFpp/ffpp_fake_ids.npy", merged_ids)
np.save("./id_vectors/FFpp/ffpp_fake_len.npy", merged_len)

# %% [markdown]
# ### 1.2. CelebDF

# %%
save_root = "./id_vectors/CelebDF/"

paths=["/media/baoping/8TSGHDD/CelebDF/Celeb-real/aligned_faces", \
       "/media/baoping/8TSGHDD/CelebDF/Celeb-synthesis/aligned_faces"]

ids_save_path = ["celebdf_real.npy", "celebdf_fake.npy"]
len_save_path = ["celebdf_real_lens.npy", "celebdf_fake_lens.npy"]
for idx, p in enumerate(paths):
    video_id_extraction(p, 
                        os.path.join(save_root, ids_save_path[idx]), 
                        os.path.join(save_root, len_save_path[idx]))

# %% [markdown]
# ### 1.3. DFD

# %%
save_root = "./id_vectors/DFD/"

paths=["/media/baoping/8TSGHDD/DeepFakeDetection/real", \
       "/media/baoping/8TSGHDD/DeepFakeDetection/fake"]

ids_save_path = ["dfd_real.npy", "dfd_fake.npy"]
len_save_path = ["dfd_real_lens.npy", "dfd_fake_lens.npy"]
for idx, p in enumerate(paths):
    video_id_extraction(p, 
                        os.path.join(save_root, ids_save_path[idx]), 
                        os.path.join(save_root, len_save_path[idx]))

# %% [markdown]
# ### 1.4.Deeper

# %%
save_root = "./id_vectors/Deeper/"

paths=["/media/baoping/8TSGHDD/DeeperForensics1.0/manipulated_videos/end_to_end"]

ids_save_path = ["deeper_fake.npy"]
len_save_path = ["deeper_fake_lens.npy"]
for idx, p in enumerate(paths):
    video_id_extraction(p, 
                        os.path.join(save_root, ids_save_path[idx]), 
                        os.path.join(save_root, len_save_path[idx]))

# %% [markdown]
# # 2. TI2Net training

# %%
# !python train.py \
--fake_selection="all" \
--model="test" \
--train_contrastive=1 \
--real_path="./id_vectors/real_ids.npy" \
--real_len_path="./id_vectors/real_lens.npy" \
--fake_path="./id_vectors/fake_ids.npy" \
--fake_len_path="./id_vectors/fake_lens.npy"
# Out:
# Using device: cuda:0
# train set and test and set get
# Training contrastive module
# model TI2Net(
#   (dropout_landmark): LandmarkDropout()
#   (rnn): GRU(1024, 512, batch_first=True, bidirectional=True)
#   (dropout_feature): Dropout(p=0.7, inplace=False)
#   (linear_1): Linear(in_features=1024, out_features=128, bias=True)
#   (relu): ReLU()
#   (linear_2): Linear(in_features=128, out_features=2, bias=True)
#   (output): Softmax(dim=1)
# )
# Using TripletMarginLoss
# train iteration each epoch: 3000
# test iteration each epoch: 1000
# ***************************************************************************************************
# epoch:1 training: emb_loss:0.5005 clf_loss:0.65, loss:0.655, train_acc:0.6264save the model to ./weights/torch/test.pth
# epoch:1 testing: test_seq_acc:0.562, test_seq_auc:0.4417, test_video_acc:0.562, test_video_auc:0.562save the model to ./weights/torch/test.pth
# epoch:1 summary: best_seq_acc:0.562 best_seq_auc:0.4417 best_video_acc:0.562 best_video_auc:0.562save the model to ./weights/torch/test.pth
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:2 training: emb_loss:0.7401 clf_loss:0.597, loss:0.6044, train_acc:0.6761save the model to ./weights/torch/test.pth
# epoch:2 testing: test_seq_acc:0.829, test_seq_auc:0.8781, test_video_acc:0.829, test_video_auc:0.8781save the model to ./weights/torch/test.pth
# epoch:2 summary: best_seq_acc:0.829 best_seq_auc:0.8781 best_video_acc:0.829 best_video_auc:0.8781save the model to ./weights/torch/test.pth
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:3 training: emb_loss:0.5309 clf_loss:0.5799, loss:0.5852, train_acc:0.6833
# epoch:3 testing: test_seq_acc:0.723, test_seq_auc:0.8989, test_video_acc:0.723, test_video_auc:0.8989
# epoch:3 summary: best_seq_acc:0.829 best_seq_auc:0.8989 best_video_acc:0.829 best_video_auc:0.8989
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:4 training: emb_loss:0.4428 clf_loss:0.5735, loss:0.5779, train_acc:0.6872
# epoch:4 testing: test_seq_acc:0.741, test_seq_auc:0.9272, test_video_acc:0.741, test_video_auc:0.9272
# epoch:4 summary: best_seq_acc:0.829 best_seq_auc:0.9272 best_video_acc:0.829 best_video_auc:0.9272
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:5 training: emb_loss:0.4316 clf_loss:0.5694, loss:0.5737, train_acc:0.6908
# epoch:5 testing: test_seq_acc:0.675, test_seq_auc:0.9502, test_video_acc:0.675, test_video_auc:0.9502
# epoch:5 summary: best_seq_acc:0.829 best_seq_auc:0.9502 best_video_acc:0.829 best_video_auc:0.9502
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:6 training: emb_loss:0.4237 clf_loss:0.5695, loss:0.5737, train_acc:0.6899
# epoch:6 testing: test_seq_acc:0.6875, test_seq_auc:0.9497, test_video_acc:0.6875, test_video_auc:0.9497
# epoch:6 summary: best_seq_acc:0.829 best_seq_auc:0.9502 best_video_acc:0.829 best_video_auc:0.9502
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:7 training: emb_loss:0.3743 clf_loss:0.5645, loss:0.5683, train_acc:0.705save the model to ./weights/torch/test.pth
# epoch:7 testing: test_seq_acc:0.8715, test_seq_auc:0.9689, test_video_acc:0.8715, test_video_auc:0.9689save the model to ./weights/torch/test.pth
# epoch:7 summary: best_seq_acc:0.8715 best_seq_auc:0.9689 best_video_acc:0.8715 best_video_auc:0.9689save the model to ./weights/torch/test.pth
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:8 training: emb_loss:0.4487 clf_loss:0.5629, loss:0.5674, train_acc:0.7059
# epoch:8 testing: test_seq_acc:0.8565, test_seq_auc:0.948, test_video_acc:0.8565, test_video_auc:0.948
# epoch:8 summary: best_seq_acc:0.8715 best_seq_auc:0.9689 best_video_acc:0.8715 best_video_auc:0.9689
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:9 training: emb_loss:0.3924 clf_loss:0.5597, loss:0.5636, train_acc:0.7092
# epoch:9 testing: test_seq_acc:0.764, test_seq_auc:0.9749, test_video_acc:0.764, test_video_auc:0.9749
# epoch:9 summary: best_seq_acc:0.8715 best_seq_auc:0.9749 best_video_acc:0.8715 best_video_auc:0.9749
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:10 training: emb_loss:0.366 clf_loss:0.5573, loss:0.561, train_acc:0.7158save the model to ./weights/torch/test.pth
# epoch:10 testing: test_seq_acc:0.8875, test_seq_auc:0.9845, test_video_acc:0.8875, test_video_auc:0.9845save the model to ./weights/torch/test.pth
# epoch:10 summary: best_seq_acc:0.8875 best_seq_auc:0.9845 best_video_acc:0.8875 best_video_auc:0.9845save the model to ./weights/torch/test.pth
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:11 training: emb_loss:0.3338 clf_loss:0.5479, loss:0.5512, train_acc:0.7318save the model to ./weights/torch/test.pth
# epoch:11 testing: test_seq_acc:0.9, test_seq_auc:0.9776, test_video_acc:0.9, test_video_auc:0.9776save the model to ./weights/torch/test.pth
# epoch:11 summary: best_seq_acc:0.9 best_seq_auc:0.9845 best_video_acc:0.9 best_video_auc:0.9845save the model to ./weights/torch/test.pth
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:12 training: emb_loss:0.3522 clf_loss:0.5434, loss:0.547, train_acc:0.7408save the model to ./weights/torch/test.pth
# epoch:12 testing: test_seq_acc:0.905, test_seq_auc:0.9838, test_video_acc:0.905, test_video_auc:0.9838save the model to ./weights/torch/test.pth
# epoch:12 summary: best_seq_acc:0.905 best_seq_auc:0.9845 best_video_acc:0.905 best_video_auc:0.9845save the model to ./weights/torch/test.pth
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:13 training: emb_loss:0.3718 clf_loss:0.5389, loss:0.5426, train_acc:0.7453
# epoch:13 testing: test_seq_acc:0.679, test_seq_auc:0.9837, test_video_acc:0.679, test_video_auc:0.9837
# epoch:13 summary: best_seq_acc:0.905 best_seq_auc:0.9845 best_video_acc:0.905 best_video_auc:0.9845
# ***************************************************************************************************
# ***************************************************************************************************
# epoch:14 training: emb_loss:0.3459 clf_loss:0.5388, loss:0.5423, train_acc:0.7511
# epoch:14 testing: test_seq_acc:0.839, test_seq_auc:0.9764, test_video_acc:0.839, test_video_auc:0.9764
# epoch:14 summary: best_seq_acc:0.905 best_seq_auc:0.9845 best_video_acc:0.905 best_video_auc:0.9845
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:15 training: emb_loss:0.3245 clf_loss:0.5313, loss:0.5345, train_acc:0.7593save the model to ./weights/torch/test.pth
# epoch:15 testing: test_seq_acc:0.9055, test_seq_auc:0.9863, test_video_acc:0.9055, test_video_auc:0.9863save the model to ./weights/torch/test.pth
# epoch:15 summary: best_seq_acc:0.9055 best_seq_auc:0.9863 best_video_acc:0.9055 best_video_auc:0.9863save the model to ./weights/torch/test.pth
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:16 training: emb_loss:0.3646 clf_loss:0.5245, loss:0.5282, train_acc:0.7711save the model to ./weights/torch/test.pth
# epoch:16 testing: test_seq_acc:0.941, test_seq_auc:0.9759, test_video_acc:0.941, test_video_auc:0.9759save the model to ./weights/torch/test.pth
# epoch:16 summary: best_seq_acc:0.941 best_seq_auc:0.9863 best_video_acc:0.941 best_video_auc:0.9863save the model to ./weights/torch/test.pth
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:17 training: emb_loss:0.3575 clf_loss:0.5228, loss:0.5264, train_acc:0.7739
# epoch:17 testing: test_seq_acc:0.9305, test_seq_auc:0.9891, test_video_acc:0.9305, test_video_auc:0.9891
# epoch:17 summary: best_seq_acc:0.941 best_seq_auc:0.9891 best_video_acc:0.941 best_video_auc:0.9891
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:18 training: emb_loss:0.3353 clf_loss:0.5166, loss:0.5199, train_acc:0.7806
# epoch:18 testing: test_seq_acc:0.8915, test_seq_auc:0.992, test_video_acc:0.8915, test_video_auc:0.992
# epoch:18 summary: best_seq_acc:0.941 best_seq_auc:0.992 best_video_acc:0.941 best_video_auc:0.992
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:19 training: emb_loss:0.3046 clf_loss:0.5135, loss:0.5165, train_acc:0.7883
# epoch:19 testing: test_seq_acc:0.8515, test_seq_auc:0.9945, test_video_acc:0.8515, test_video_auc:0.9945
# epoch:19 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:20 training: emb_loss:0.2814 clf_loss:0.5053, loss:0.5081, train_acc:0.7933
# epoch:20 testing: test_seq_acc:0.9325, test_seq_auc:0.9835, test_video_acc:0.9325, test_video_auc:0.9835
# epoch:20 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:21 training: emb_loss:0.2866 clf_loss:0.5024, loss:0.5053, train_acc:0.7994
# epoch:21 testing: test_seq_acc:0.787, test_seq_auc:0.9779, test_video_acc:0.787, test_video_auc:0.9779
# epoch:21 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:22 training: emb_loss:0.2759 clf_loss:0.503, loss:0.5058, train_acc:0.7954
# epoch:22 testing: test_seq_acc:0.8485, test_seq_auc:0.9889, test_video_acc:0.8485, test_video_auc:0.9889
# epoch:22 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:23 training: emb_loss:0.2763 clf_loss:0.4995, loss:0.5023, train_acc:0.8027
# epoch:23 testing: test_seq_acc:0.865, test_seq_auc:0.9888, test_video_acc:0.865, test_video_auc:0.9888
# epoch:23 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:24 training: emb_loss:0.2455 clf_loss:0.498, loss:0.5004, train_acc:0.8042
# epoch:24 testing: test_seq_acc:0.8915, test_seq_auc:0.976, test_video_acc:0.8915, test_video_auc:0.976
# epoch:24 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:25 training: emb_loss:0.2131 clf_loss:0.4938, loss:0.4959, train_acc:0.8046
# epoch:25 testing: test_seq_acc:0.7925, test_seq_auc:0.972, test_video_acc:0.7925, test_video_auc:0.972
# epoch:25 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:26 training: emb_loss:0.2228 clf_loss:0.4916, loss:0.4938, train_acc:0.8117
# epoch:26 testing: test_seq_acc:0.622, test_seq_auc:0.9807, test_video_acc:0.622, test_video_auc:0.9807
# epoch:26 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:27 training: emb_loss:0.2428 clf_loss:0.4851, loss:0.4876, train_acc:0.8174
# epoch:27 testing: test_seq_acc:0.8515, test_seq_auc:0.9733, test_video_acc:0.8515, test_video_auc:0.9733
# epoch:27 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
# ***************************************************************************************************
# epoch:28 training: emb_loss:0.2138 clf_loss:0.4759, loss:0.478, train_acc:0.8288
# epoch:28 testing: test_seq_acc:0.8995, test_seq_auc:0.981, test_video_acc:0.8995, test_video_auc:0.981
# epoch:28 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:29 training: emb_loss:0.2266 clf_loss:0.4805, loss:0.4828, train_acc:0.8203
# epoch:29 testing: test_seq_acc:0.882, test_seq_auc:0.9888, test_video_acc:0.882, test_video_auc:0.9888
# epoch:29 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:30 training: emb_loss:0.2081 clf_loss:0.4763, loss:0.4784, train_acc:0.8287
# epoch:30 testing: test_seq_acc:0.9275, test_seq_auc:0.9803, test_video_acc:0.9275, test_video_auc:0.9803
# epoch:30 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:31 training: emb_loss:0.2117 clf_loss:0.4794, loss:0.4816, train_acc:0.8209
# epoch:31 testing: test_seq_acc:0.8635, test_seq_auc:0.9817, test_video_acc:0.8635, test_video_auc:0.9817
# epoch:31 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:32 training: emb_loss:0.2142 clf_loss:0.4729, loss:0.4751, train_acc:0.831
# epoch:32 testing: test_seq_acc:0.8085, test_seq_auc:0.9824, test_video_acc:0.8085, test_video_auc:0.9824
# epoch:32 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:33 training: emb_loss:0.1916 clf_loss:0.4718, loss:0.4737, train_acc:0.8336
# epoch:33 testing: test_seq_acc:0.787, test_seq_auc:0.9823, test_video_acc:0.787, test_video_auc:0.9823
# epoch:33 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:34 training: emb_loss:0.1869 clf_loss:0.468, loss:0.4699, train_acc:0.8368
# epoch:34 testing: test_seq_acc:0.8745, test_seq_auc:0.9755, test_video_acc:0.8745, test_video_auc:0.9755
# epoch:34 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:35 training: emb_loss:0.2015 clf_loss:0.4679, loss:0.4699, train_acc:0.8369
# epoch:35 testing: test_seq_acc:0.88, test_seq_auc:0.9785, test_video_acc:0.88, test_video_auc:0.9785
# epoch:35 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:36 training: emb_loss:0.1929 clf_loss:0.4687, loss:0.4706, train_acc:0.8343
# epoch:36 testing: test_seq_acc:0.8645, test_seq_auc:0.9723, test_video_acc:0.8645, test_video_auc:0.9723
# epoch:36 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:37 training: emb_loss:0.1546 clf_loss:0.462, loss:0.4635, train_acc:0.8419
# epoch:37 testing: test_seq_acc:0.7885, test_seq_auc:0.9274, test_video_acc:0.7885, test_video_auc:0.9274
# epoch:37 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:38 training: emb_loss:0.1642 clf_loss:0.4646, loss:0.4662, train_acc:0.8371
# epoch:38 testing: test_seq_acc:0.761, test_seq_auc:0.9644, test_video_acc:0.761, test_video_auc:0.9644
# epoch:38 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:39 training: emb_loss:0.1758 clf_loss:0.4617, loss:0.4635, train_acc:0.8461
# epoch:39 testing: test_seq_acc:0.8115, test_seq_auc:0.93, test_video_acc:0.8115, test_video_auc:0.93
# epoch:39 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:40 training: emb_loss:0.1525 clf_loss:0.4584, loss:0.4599, train_acc:0.8459
# epoch:40 testing: test_seq_acc:0.932, test_seq_auc:0.9742, test_video_acc:0.932, test_video_auc:0.9742
# epoch:40 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:41 training: emb_loss:0.1456 clf_loss:0.4547, loss:0.4562, train_acc:0.8496
# epoch:41 testing: test_seq_acc:0.833, test_seq_auc:0.9746, test_video_acc:0.833, test_video_auc:0.9746
# epoch:41 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:42 training: emb_loss:0.1476 clf_loss:0.4496, loss:0.4511, train_acc:0.8558
# epoch:42 testing: test_seq_acc:0.894, test_seq_auc:0.9714, test_video_acc:0.894, test_video_auc:0.9714
# epoch:42 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
# ***************************************************************************************************
# epoch:43 training: emb_loss:0.1892 clf_loss:0.4566, loss:0.4585, train_acc:0.8492
# epoch:43 testing: test_seq_acc:0.9025, test_seq_auc:0.975, test_video_acc:0.9025, test_video_auc:0.975
# epoch:43 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:44 training: emb_loss:0.1488 clf_loss:0.4501, loss:0.4516, train_acc:0.8556
# epoch:44 testing: test_seq_acc:0.8085, test_seq_auc:0.9714, test_video_acc:0.8085, test_video_auc:0.9714
# epoch:44 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:45 training: emb_loss:0.1341 clf_loss:0.4467, loss:0.448, train_acc:0.8583
# epoch:45 testing: test_seq_acc:0.8065, test_seq_auc:0.973, test_video_acc:0.8065, test_video_auc:0.973
# epoch:45 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:46 training: emb_loss:0.1469 clf_loss:0.4466, loss:0.4481, train_acc:0.8616
# epoch:46 testing: test_seq_acc:0.751, test_seq_auc:0.9724, test_video_acc:0.751, test_video_auc:0.9724
# epoch:46 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:47 training: emb_loss:0.1364 clf_loss:0.4481, loss:0.4494, train_acc:0.8588
# epoch:47 testing: test_seq_acc:0.8505, test_seq_auc:0.9811, test_video_acc:0.8505, test_video_auc:0.9811
# epoch:47 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:48 training: emb_loss:0.1351 clf_loss:0.4455, loss:0.4468, train_acc:0.8626
# epoch:48 testing: test_seq_acc:0.8615, test_seq_auc:0.9647, test_video_acc:0.8615, test_video_auc:0.9647
# epoch:48 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:49 training: emb_loss:0.132 clf_loss:0.4408, loss:0.4421, train_acc:0.8656
# epoch:49 testing: test_seq_acc:0.8235, test_seq_auc:0.9538, test_video_acc:0.8235, test_video_auc:0.9538
# epoch:49 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:50 training: emb_loss:0.1365 clf_loss:0.4397, loss:0.441, train_acc:0.8666
# epoch:50 testing: test_seq_acc:0.7785, test_seq_auc:0.8824, test_video_acc:0.7785, test_video_auc:0.8824
# epoch:50 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:51 training: emb_loss:0.1387 clf_loss:0.441, loss:0.4424, train_acc:0.8643
# epoch:51 testing: test_seq_acc:0.7865, test_seq_auc:0.9777, test_video_acc:0.7865, test_video_auc:0.9777
# epoch:51 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:52 training: emb_loss:0.1426 clf_loss:0.4383, loss:0.4397, train_acc:0.8708
# epoch:52 testing: test_seq_acc:0.724, test_seq_auc:0.9763, test_video_acc:0.724, test_video_auc:0.9763
# epoch:52 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:53 training: emb_loss:0.1249 clf_loss:0.4365, loss:0.4378, train_acc:0.8714
# epoch:53 testing: test_seq_acc:0.658, test_seq_auc:0.9439, test_video_acc:0.658, test_video_auc:0.9439
# epoch:53 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:54 training: emb_loss:0.1147 clf_loss:0.4389, loss:0.4401, train_acc:0.8673
# epoch:54 testing: test_seq_acc:0.814, test_seq_auc:0.9573, test_video_acc:0.814, test_video_auc:0.9573
# epoch:54 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:55 training: emb_loss:0.125 clf_loss:0.4357, loss:0.4369, train_acc:0.8714
# epoch:55 testing: test_seq_acc:0.766, test_seq_auc:0.9472, test_video_acc:0.766, test_video_auc:0.9472
# epoch:55 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:56 training: emb_loss:0.1254 clf_loss:0.434, loss:0.4353, train_acc:0.8733
# epoch:56 testing: test_seq_acc:0.7145, test_seq_auc:0.9436, test_video_acc:0.7145, test_video_auc:0.9436
# epoch:56 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:57 training: emb_loss:0.1172 clf_loss:0.4351, loss:0.4363, train_acc:0.8704
# epoch:57 testing: test_seq_acc:0.7045, test_seq_auc:0.8782, test_video_acc:0.7045, test_video_auc:0.8782
# epoch:57 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
# ***************************************************************************************************
# epoch:58 training: emb_loss:0.1147 clf_loss:0.435, loss:0.4361, train_acc:0.872
# epoch:58 testing: test_seq_acc:0.653, test_seq_auc:0.9032, test_video_acc:0.653, test_video_auc:0.9032
# epoch:58 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:59 training: emb_loss:0.1266 clf_loss:0.4345, loss:0.4357, train_acc:0.8736
# epoch:59 testing: test_seq_acc:0.785, test_seq_auc:0.908, test_video_acc:0.785, test_video_auc:0.908
# epoch:59 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:60 training: emb_loss:0.1164 clf_loss:0.427, loss:0.4281, train_acc:0.8801
# epoch:60 testing: test_seq_acc:0.591, test_seq_auc:0.9101, test_video_acc:0.591, test_video_auc:0.9101
# epoch:60 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:61 training: emb_loss:0.1002 clf_loss:0.4301, loss:0.4311, train_acc:0.8766
# epoch:61 testing: test_seq_acc:0.7905, test_seq_auc:0.9557, test_video_acc:0.7905, test_video_auc:0.9557
# epoch:61 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:62 training: emb_loss:0.1216 clf_loss:0.4299, loss:0.4311, train_acc:0.8793
# epoch:62 testing: test_seq_acc:0.7045, test_seq_auc:0.9379, test_video_acc:0.7045, test_video_auc:0.9379
# epoch:62 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:63 training: emb_loss:0.1061 clf_loss:0.4273, loss:0.4284, train_acc:0.8808
# epoch:63 testing: test_seq_acc:0.701, test_seq_auc:0.9523, test_video_acc:0.701, test_video_auc:0.9523
# epoch:63 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:64 training: emb_loss:0.1087 clf_loss:0.4298, loss:0.4309, train_acc:0.876
# epoch:64 testing: test_seq_acc:0.7945, test_seq_auc:0.9389, test_video_acc:0.7945, test_video_auc:0.9389
# epoch:64 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:65 training: emb_loss:0.1129 clf_loss:0.43, loss:0.4311, train_acc:0.8781
# epoch:65 testing: test_seq_acc:0.6785, test_seq_auc:0.9594, test_video_acc:0.6785, test_video_auc:0.9594
# epoch:65 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:66 training: emb_loss:0.1102 clf_loss:0.4309, loss:0.432, train_acc:0.8768
# epoch:66 testing: test_seq_acc:0.7435, test_seq_auc:0.9707, test_video_acc:0.7435, test_video_auc:0.9707
# epoch:66 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:67 training: emb_loss:0.09572 clf_loss:0.4214, loss:0.4224, train_acc:0.8859
# epoch:67 testing: test_seq_acc:0.6325, test_seq_auc:0.9112, test_video_acc:0.6325, test_video_auc:0.9112
# epoch:67 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:68 training: emb_loss:0.1144 clf_loss:0.4301, loss:0.4312, train_acc:0.8747
# epoch:68 testing: test_seq_acc:0.7165, test_seq_auc:0.8639, test_video_acc:0.7165, test_video_auc:0.8639
# epoch:68 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:69 training: emb_loss:0.1036 clf_loss:0.4229, loss:0.424, train_acc:0.8859
# epoch:69 testing: test_seq_acc:0.6465, test_seq_auc:0.9372, test_video_acc:0.6465, test_video_auc:0.9372
# epoch:69 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:70 training: emb_loss:0.0958 clf_loss:0.4241, loss:0.4251, train_acc:0.882
# epoch:70 testing: test_seq_acc:0.75, test_seq_auc:0.9383, test_video_acc:0.75, test_video_auc:0.9383
# epoch:70 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:71 training: emb_loss:0.09244 clf_loss:0.4226, loss:0.4235, train_acc:0.8846
# epoch:71 testing: test_seq_acc:0.563, test_seq_auc:0.8505, test_video_acc:0.563, test_video_auc:0.8505
# epoch:71 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:72 training: emb_loss:0.0982 clf_loss:0.4163, loss:0.4173, train_acc:0.8908
# epoch:72 testing: test_seq_acc:0.718, test_seq_auc:0.9453, test_video_acc:0.718, test_video_auc:0.9453
# epoch:72 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
# ***************************************************************************************************
# epoch:73 training: emb_loss:0.107 clf_loss:0.4168, loss:0.4179, train_acc:0.8909
# epoch:73 testing: test_seq_acc:0.7255, test_seq_auc:0.9064, test_video_acc:0.7255, test_video_auc:0.9064
# epoch:73 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:74 training: emb_loss:0.09335 clf_loss:0.4184, loss:0.4193, train_acc:0.8886
# epoch:74 testing: test_seq_acc:0.6835, test_seq_auc:0.8801, test_video_acc:0.6835, test_video_auc:0.8801
# epoch:74 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:75 training: emb_loss:0.1004 clf_loss:0.4192, loss:0.4202, train_acc:0.8889
# epoch:75 testing: test_seq_acc:0.69, test_seq_auc:0.8973, test_video_acc:0.69, test_video_auc:0.8973
# epoch:75 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:76 training: emb_loss:0.1009 clf_loss:0.4227, loss:0.4237, train_acc:0.8856
# epoch:76 testing: test_seq_acc:0.7, test_seq_auc:0.8584, test_video_acc:0.7, test_video_auc:0.8584
# epoch:76 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:77 training: emb_loss:0.09909 clf_loss:0.4192, loss:0.4202, train_acc:0.89
# epoch:77 testing: test_seq_acc:0.7705, test_seq_auc:0.9029, test_video_acc:0.7705, test_video_auc:0.9029
# epoch:77 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:78 training: emb_loss:0.09727 clf_loss:0.4189, loss:0.4199, train_acc:0.8892
# epoch:78 testing: test_seq_acc:0.6895, test_seq_auc:0.8693, test_video_acc:0.6895, test_video_auc:0.8693
# epoch:78 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:79 training: emb_loss:0.08652 clf_loss:0.4179, loss:0.4188, train_acc:0.8909
# epoch:79 testing: test_seq_acc:0.669, test_seq_auc:0.8604, test_video_acc:0.669, test_video_auc:0.8604
# epoch:79 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:80 training: emb_loss:0.0922 clf_loss:0.4155, loss:0.4164, train_acc:0.8942
# epoch:80 testing: test_seq_acc:0.6815, test_seq_auc:0.8937, test_video_acc:0.6815, test_video_auc:0.8937
# epoch:80 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:81 training: emb_loss:0.08035 clf_loss:0.4164, loss:0.4172, train_acc:0.8922
# epoch:81 testing: test_seq_acc:0.6425, test_seq_auc:0.8709, test_video_acc:0.6425, test_video_auc:0.8709
# epoch:81 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:82 training: emb_loss:0.0792 clf_loss:0.4135, loss:0.4143, train_acc:0.8929
# epoch:82 testing: test_seq_acc:0.6555, test_seq_auc:0.8583, test_video_acc:0.6555, test_video_auc:0.8583
# epoch:82 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:83 training: emb_loss:0.08685 clf_loss:0.4122, loss:0.4131, train_acc:0.8961
# epoch:83 testing: test_seq_acc:0.767, test_seq_auc:0.9065, test_video_acc:0.767, test_video_auc:0.9065
# ...
#
#
# ***************************************************************************************************
# epoch:173 training: emb_loss:0.0371 clf_loss:0.3765, loss:0.3769, train_acc:0.9326
# epoch:173 testing: test_seq_acc:0.5635, test_seq_auc:0.7379, test_video_acc:0.5635, test_video_auc:0.7379
# epoch:173 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:174 training: emb_loss:0.03979 clf_loss:0.3771, loss:0.3775, train_acc:0.9344
# epoch:174 testing: test_seq_acc:0.5195, test_seq_auc:0.7082, test_video_acc:0.5195, test_video_auc:0.7082
# epoch:174 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:175 training: emb_loss:0.04476 clf_loss:0.3808, loss:0.3812, train_acc:0.9284
# epoch:175 testing: test_seq_acc:0.524, test_seq_auc:0.6099, test_video_acc:0.524, test_video_auc:0.6099
# epoch:175 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:176 training: emb_loss:0.05867 clf_loss:0.3834, loss:0.384, train_acc:0.9268
# epoch:176 testing: test_seq_acc:0.5105, test_seq_auc:0.7035, test_video_acc:0.5105, test_video_auc:0.7035
# epoch:176 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:177 training: emb_loss:0.04485 clf_loss:0.3787, loss:0.3792, train_acc:0.9322
# epoch:177 testing: test_seq_acc:0.4995, test_seq_auc:0.686, test_video_acc:0.4995, test_video_auc:0.686
# epoch:177 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
# ***************************************************************************************************
# epoch:178 training: emb_loss:0.04228 clf_loss:0.3773, loss:0.3777, train_acc:0.9336
# epoch:178 testing: test_seq_acc:0.514, test_seq_auc:0.6276, test_video_acc:0.514, test_video_auc:0.6276
# epoch:178 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:179 training: emb_loss:0.04931 clf_loss:0.3742, loss:0.3747, train_acc:0.9359
# epoch:179 testing: test_seq_acc:0.506, test_seq_auc:0.5458, test_video_acc:0.506, test_video_auc:0.5458
# epoch:179 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:180 training: emb_loss:0.04672 clf_loss:0.383, loss:0.3835, train_acc:0.9269
# epoch:180 testing: test_seq_acc:0.4995, test_seq_auc:0.5908, test_video_acc:0.4995, test_video_auc:0.5908
# epoch:180 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:181 training: emb_loss:0.04142 clf_loss:0.3813, loss:0.3817, train_acc:0.9288
# epoch:181 testing: test_seq_acc:0.483, test_seq_auc:0.6407, test_video_acc:0.483, test_video_auc:0.6407
# epoch:181 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:182 training: emb_loss:0.04508 clf_loss:0.3797, loss:0.3802, train_acc:0.9308
# epoch:182 testing: test_seq_acc:0.4785, test_seq_auc:0.6177, test_video_acc:0.4785, test_video_auc:0.6177
# epoch:182 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:183 training: emb_loss:0.04397 clf_loss:0.3754, loss:0.3759, train_acc:0.936
# epoch:183 testing: test_seq_acc:0.492, test_seq_auc:0.6362, test_video_acc:0.492, test_video_auc:0.6362
# epoch:183 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:184 training: emb_loss:0.04284 clf_loss:0.3764, loss:0.3768, train_acc:0.9341
# epoch:184 testing: test_seq_acc:0.4775, test_seq_auc:0.6328, test_video_acc:0.4775, test_video_auc:0.6328
# epoch:184 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:185 training: emb_loss:0.03806 clf_loss:0.3755, loss:0.3759, train_acc:0.9351
# epoch:185 testing: test_seq_acc:0.487, test_seq_auc:0.6764, test_video_acc:0.487, test_video_auc:0.6764
# epoch:185 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:186 training: emb_loss:0.04057 clf_loss:0.3756, loss:0.376, train_acc:0.9349
# epoch:186 testing: test_seq_acc:0.4985, test_seq_auc:0.6151, test_video_acc:0.4985, test_video_auc:0.6151
# epoch:186 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:187 training: emb_loss:0.03335 clf_loss:0.3785, loss:0.3788, train_acc:0.9321
# epoch:187 testing: test_seq_acc:0.5365, test_seq_auc:0.6623, test_video_acc:0.5365, test_video_auc:0.6623
# epoch:187 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:188 training: emb_loss:0.04299 clf_loss:0.3788, loss:0.3792, train_acc:0.9321
# epoch:188 testing: test_seq_acc:0.498, test_seq_auc:0.7356, test_video_acc:0.498, test_video_auc:0.7356
# epoch:188 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:189 training: emb_loss:0.0403 clf_loss:0.3776, loss:0.378, train_acc:0.9324
# epoch:189 testing: test_seq_acc:0.52, test_seq_auc:0.7426, test_video_acc:0.52, test_video_auc:0.7426
# epoch:189 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:190 training: emb_loss:0.04061 clf_loss:0.3782, loss:0.3786, train_acc:0.933
# epoch:190 testing: test_seq_acc:0.543, test_seq_auc:0.6333, test_video_acc:0.543, test_video_auc:0.6333
# epoch:190 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:191 training: emb_loss:0.04291 clf_loss:0.3768, loss:0.3772, train_acc:0.9338
# epoch:191 testing: test_seq_acc:0.515, test_seq_auc:0.6836, test_video_acc:0.515, test_video_auc:0.6836
# epoch:191 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:192 training: emb_loss:0.03917 clf_loss:0.3754, loss:0.3758, train_acc:0.9352
# epoch:192 testing: test_seq_acc:0.4785, test_seq_auc:0.5998, test_video_acc:0.4785, test_video_auc:0.5998
# epoch:192 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
# ***************************************************************************************************
# epoch:193 training: emb_loss:0.05365 clf_loss:0.3779, loss:0.3785, train_acc:0.9331
# epoch:193 testing: test_seq_acc:0.5145, test_seq_auc:0.6053, test_video_acc:0.5145, test_video_auc:0.6053
# epoch:193 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:194 training: emb_loss:0.04582 clf_loss:0.372, loss:0.3725, train_acc:0.9377
# epoch:194 testing: test_seq_acc:0.512, test_seq_auc:0.5048, test_video_acc:0.512, test_video_auc:0.512
# epoch:194 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:195 training: emb_loss:0.0432 clf_loss:0.3746, loss:0.3751, train_acc:0.9359
# epoch:195 testing: test_seq_acc:0.497, test_seq_auc:0.4847, test_video_acc:0.497, test_video_auc:0.497
# epoch:195 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:196 training: emb_loss:0.04551 clf_loss:0.3786, loss:0.3791, train_acc:0.9311
# epoch:196 testing: test_seq_acc:0.496, test_seq_auc:0.5902, test_video_acc:0.496, test_video_auc:0.5902
# epoch:196 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:197 training: emb_loss:0.03896 clf_loss:0.3749, loss:0.3753, train_acc:0.9356
# epoch:197 testing: test_seq_acc:0.511, test_seq_auc:0.522, test_video_acc:0.511, test_video_auc:0.522
# epoch:197 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:198 training: emb_loss:0.03701 clf_loss:0.3742, loss:0.3745, train_acc:0.9346
# epoch:198 testing: test_seq_acc:0.4545, test_seq_auc:0.6059, test_video_acc:0.4545, test_video_auc:0.6059
# epoch:198 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:199 training: emb_loss:0.0346 clf_loss:0.369, loss:0.3693, train_acc:0.9428
# epoch:199 testing: test_seq_acc:0.5295, test_seq_auc:0.6517, test_video_acc:0.5295, test_video_auc:0.6517
# epoch:199 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# ***************************************************************************************************
# epoch:200 training: emb_loss:0.05221 clf_loss:0.3763, loss:0.3768, train_acc:0.9344
# epoch:200 testing: test_seq_acc:0.4855, test_seq_auc:0.514, test_video_acc:0.4855, test_video_auc:0.514
# epoch:200 summary: best_seq_acc:0.941 best_seq_auc:0.9945 best_video_acc:0.941 best_video_auc:0.9945
# ***************************************************************************************************
#
#
# 100%|█████████████████████████████████████████| 200/200 [48:54<00:00, 14.67s/it]

# %% [markdown]
# # 3. TI2Net evaluation

# %%
# !python evaluate.py \
--model="test.pth" \
--real_id_path="./id_vectors/FFpp/ffpp_real_ids_test.npy" \
--real_len_path="./id_vectors/FFpp/ffpp_real_lens_test.npy" \
--fake_id_path="./id_vectors/FFpp/ffpp_fake_ids_test.npy" \
--fake_len_path="./id_vectors/FFpp/ffpp_fake_lens_test.npy"
# Out:
# Using device: cuda:0
# Please register the status.
#
#
# #----Evaluation Results----#
# Accuracy (sequence-level): 0.99
# AUC (sequence-level): 0.998
# Accuracy (video-level): 0.99
# AUC (video-level): 0.998
# #------------End-----------#
